# %% [markdown]
# # 1 DOWNLOAD THE DATASET
# # 2 LOAD THE DATASET

# %%
import pandas as pd
import numpy as np
df =pd.read_csv('C:\Users\91962\Documents\IBM project\fork_project\assignments\assignment 3\manikandan [member 1]\abalone.csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # 3. PERFORM BELOW VISUALIZATIONS

# %% [markdown]
# # Univariate Analysis

# %%
import seaborn as sns
sns.histplot(df.Height,kde=True)

# %%
import seaborn as sns
sns.histplot(df.Rings,kde=True)

# %% [markdown]
# ## Bivariate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(df.Length,df.Height)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
import seaborn as sns
df= pd.read_csv("C:\Users\91962\Documents\IBM project\fork_project\assignments\assignment 3\manikandan [member 1]\abalone.csv")
sns.pairplot(df)

# %% [markdown]
# # 4. Perform descriptive statistics on the dataset.

# %%
df=pd.read_csv("C:\Users\91962\Documents\IBM project\fork_project\assignments\assignment 3\manikandan [member 1]\abalone.csv")
df.describe(include='all')
# Out:
#          Sex       Length     Diameter       Height  Whole weight  \
# count   4177  4177.000000  4177.000000  4177.000000   4177.000000
# unique     3          NaN          NaN          NaN           NaN
# top        M          NaN          NaN          NaN           NaN
# freq    1528          NaN          NaN          NaN           NaN
# mean     NaN     0.523992     0.407881     0.139516      0.828742
# std      NaN     0.120093     0.099240     0.041827      0.490389
# min      NaN     0.075000     0.055000     0.000000      0.002000
# 25%      NaN     0.450000     0.350000     0.115000      0.441500
# 50%      NaN     0.545000     0.425000     0.140000      0.799500
# 75%      NaN     0.615000     0.480000     0.165000      1.153000
# max      NaN     0.815000     0.650000     1.130000      2.825500
#
#         Shucked weight  Viscera weight  Shell weight        Rings
# count      4177.000000     4177.000000   4177.000000  4177.000000
# ...

# %% [markdown]
# # 5. Check for Missing values and deal with them.

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
df=pd.read_csv("C:\Users\91962\Documents\IBM project\fork_project\assignments\assignment 3\manikandan [member 1]\abalone.csv")
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # 6. Find the outliers and replace the outliers

# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as pyplot
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(11,6)
df=pd.read_csv("C:\Users\91962\Documents\IBM project\fork_project\assignments\assignment 3\manikandan [member 1]\abalone.csv")
df.sample(10)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1535   I   0.305     0.225   0.090        0.1465          0.0630
# 489    F   0.570     0.455   0.165        1.0595          0.4400
# 493    M   0.655     0.530   0.175        1.2635          0.4860
# 1537   I   0.350     0.260   0.075        0.1800          0.0900
# 3721   M   0.430     0.310   0.130        0.6485          0.2735
# 1487   M   0.600     0.455   0.155        0.9450          0.4365
# 645    I   0.445     0.330   0.120        0.3470          0.1200
# 1225   I   0.345     0.255   0.085        0.2005          0.1050
# 1552   I   0.390     0.285   0.100        0.2810          0.1275
# 3263   M   0.565     0.450   0.115        0.9085          0.3980
#
#       Viscera weight  Shell weight  Rings
# 1535          0.0340        0.0415      6
# 489           0.2195        0.2850     14
# 493           0.2635        0.4150     15
# 1537          0.0245        0.0550      5
# ...

# %% [markdown]
# # 7. Check for Categorical columns and perform encoding.

# %%
df=pd.read_csv("C:\Users\91962\Documents\IBM project\fork_project\assignments\assignment 3\manikandan [member 1]\abalone.csv")
df.columns
import pandas as pd
import numpy as np
headers=['Sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']
import seaborn as sns
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # 8. Split the data into dependent and independent variables.

# %%
x=df.iloc[:,:-1].values
print(x)
y=df.iloc[:,-1]._values
print(y)
# Out:
# [['M' 0.455 0.365 ... 0.2245 0.101 0.15]
#  ['M' 0.35 0.265 ... 0.0995 0.0485 0.07]
#  ['F' 0.53 0.42 ... 0.2565 0.1415 0.21]
#  ...
#  ['M' 0.6 0.475 ... 0.5255 0.2875 0.308]
#  ['F' 0.625 0.485 ... 0.531 0.261 0.296]
#  ['M' 0.71 0.555 ... 0.9455 0.3765 0.495]]
# [15  7  9 ...  9 10 12]

# %% [markdown]
# # 9. Scale the independent variables

# %%
import seaborn as sns
df=pd.read_csv("C:\Users\91962\Documents\IBM project\fork_project\assignments\assignment 3\manikandan [member 1]\abalone.csv")
dff=df[['Length','Height']]
sns.heatmap(dff.corr(), annot=True)
sns.set(rc={'figure.figsize':(40,40)})

# %% [markdown]
# # 10. Split the data into training and testing

# %%
from scipy.sparse.construct import random
x=df.iloc[:, 1:2].values
y=df.iloc[:,2].values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print('Row count of x_train table'+'-'+str(f"{len(x_train):,}"))
print('Row count of y_train table'+'-'+str(f"{len(y_train):,}"))
print('Row count of x_test table'+'-'+str(f"{len(x_test):,}"))
print('Row count of y_test table'+'-'+str(f"{len(y_test):,}"))

# %% [markdown]
# # 11. Build the Model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# # 12. Train the Model

# %%
model.fit(x_train,y_train)

# %% [markdown]
# # 13. Test the Model

# %%
pred=model.predict(x_test)
pred

# %%
y_p=model.predict([[2.2]])
y_p
